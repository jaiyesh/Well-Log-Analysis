# %%
import pandas as pd
import matplotlib.pyplot as plt
import lasio

# %%
file= lasio.read('15-9-19_SR_COMP.LAS')

# %%
file.well
# Out:
# [HeaderItem(mnemonic="STRT", unit="M", value="102.1568", descr="Top Depth"),
#  HeaderItem(mnemonic="STOP", unit="M", value="4636.514", descr="Bottom Depth"),
#  HeaderItem(mnemonic="STEP", unit="M", value="0.1524", descr="Depth Increment"),
#  HeaderItem(mnemonic="NULL", unit="", value="-999.25", descr="Null Value"),
#  HeaderItem(mnemonic="FLD", unit="", value="Q15", descr="Field Name"),
#  HeaderItem(mnemonic="WELL", unit="", value="15/9-19", descr="NAME"),
#  HeaderItem(mnemonic="WBN", unit="", value="15/9-19 SR", descr="WELLBORE"),
#  HeaderItem(mnemonic="NATI", unit="", value="NOR", descr="COUNTRY"),
#  HeaderItem(mnemonic="CTRY", unit="", value="NOR", descr="COUNTRY"),
#  HeaderItem(mnemonic="COMP", unit="", value="STATOIL", descr="OPERATOR"),
#  HeaderItem(mnemonic="PDAT", unit="", value="MSL", descr="PERM DATUM"),
#  HeaderItem(mnemonic="COUN", unit="", value="NORTH SEA", descr="RIG NAME"),
#  HeaderItem(mnemonic="STAT", unit="", value="NORWAY", descr="STATE"),
# ...

# %%
for i in file.well:
    print(f"{i.descr} ({i.mnemonic}): {i.value}")
# Out:
# Top Depth (STRT): 102.1568
# Bottom Depth (STOP): 4636.514
# Depth Increment (STEP): 0.1524
# Null Value (NULL): -999.25
# Field Name (FLD): Q15
# NAME (WELL): 15/9-19
# WELLBORE (WBN): 15/9-19 SR
# COUNTRY (NATI): NOR
# COUNTRY (CTRY): NOR
# OPERATOR (COMP): STATOIL
# PERM DATUM (PDAT): MSL
# RIG NAME (COUN): NORTH SEA
# STATE (STAT): NORWAY
# PB WELL ID (PBWE): 15/9-19
# PB WELLBORE ID (APIN): 15/9-19 SR
# PB WELL NAME SET (PBWS): ALL

# %%
print(file.well.WELL.value)
# Out:
# 15/9-19

# %%
file.header
# Out:
# {'Version': [HeaderItem(mnemonic="VERS", unit="", value="2.0", descr="CWLS Log ASCII Standa"),
#   HeaderItem(mnemonic="WRAP", unit="", value="NO", descr="One line per depth ste")],
#  'Well': [HeaderItem(mnemonic="STRT", unit="M", value="102.1568", descr="Top Depth"),
#   HeaderItem(mnemonic="STOP", unit="M", value="4636.514", descr="Bottom Depth"),
#   HeaderItem(mnemonic="STEP", unit="M", value="0.1524", descr="Depth Increment"),
#   HeaderItem(mnemonic="NULL", unit="", value="-999.25", descr="Null Value"),
#   HeaderItem(mnemonic="FLD", unit="", value="Q15", descr="Field Name"),
#   HeaderItem(mnemonic="WELL", unit="", value="15/9-19", descr="NAME"),
#   HeaderItem(mnemonic="WBN", unit="", value="15/9-19 SR", descr="WELLBORE"),
#   HeaderItem(mnemonic="NATI", unit="", value="NOR", descr="COUNTRY"),
#   HeaderItem(mnemonic="CTRY", unit="", value="NOR", descr="COUNTRY"),
#   HeaderItem(mnemonic="COMP", unit="", value="STATOIL", descr="OPERATOR"),
# ...

# %%
import welly

# %%
well = welly.Well.from_las('15-9-19_SR_COMP.LAS')
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\welly\well.py:194: FutureWarning: From v0.5 the default will be 'original', keeping whatever is used in the LAS file. If you want to force conversion to metres, change your code to use `index='m'`.
#   warnings.warn(m, FutureWarning)

# %%
well
# Out:
# Well(uwi: '', 7 curves: ['AC', 'CALI', 'DEN', 'GR', 'NEU', 'RDEP', 'RMED'])

# %%
well.header
# Out:
# {'name': '15/9-19', 'uwi': '', 'field': 'Q15', 'company': 'STATOIL'}

# %%
well.header.name
# Out:
# '15/9-19'

# %%
well.header.company
# Out:
# 'STATOIL'

# %%
well.count_curves()
# Out:
# 7

# %%
well.data
# Out:
# {'AC': Curve([nan, nan, nan, ..., nan, nan, nan]),
#  'CALI': Curve([nan, nan, nan, ..., nan, nan, nan]),
#  'DEN': Curve([nan, nan, nan, ..., nan, nan, nan]),
#  'GR': Curve([5.3274, 5.8235, 6.5228, ...,    nan,    nan,    nan]),
#  'NEU': Curve([nan, nan, nan, ..., nan, nan, nan]),
#  'RDEP': Curve([   nan,    nan,    nan, ..., 0.8741, 0.9002, 0.9133]),
#  'RMED': Curve([   nan,    nan,    nan, ..., 0.6888, 0.8902, 1.0363])}

# %%
df = well.df()

# %%
well.location
# Out:
# Location({'position': None, 'crs': CRS({}), 'country': 'NOR', 'state': 'NORWAY', 'td': None, 'deviation': None})

# %%
df
# Out:
#            AC  CALI  DEN      GR  NEU    RDEP    RMED
# Depth
# 102.1568  NaN   NaN  NaN  5.3274  NaN     NaN     NaN
# 102.3092  NaN   NaN  NaN  5.8235  NaN     NaN     NaN
# 102.4616  NaN   NaN  NaN  6.5228  NaN     NaN     NaN
# 102.6140  NaN   NaN  NaN  7.2285  NaN     NaN     NaN
# 102.7664  NaN   NaN  NaN  9.5020  NaN     NaN     NaN
# ...        ..   ...  ...     ...  ...     ...     ...
# 4635.9044 NaN   NaN  NaN     NaN  NaN  0.7729  0.5978
# 4636.0568 NaN   NaN  NaN     NaN  NaN  0.8369  0.6257
# 4636.2092 NaN   NaN  NaN     NaN  NaN  0.8741  0.6888
# 4636.3616 NaN   NaN  NaN     NaN  NaN  0.9002  0.8902
# 4636.5140 NaN   NaN  NaN     NaN  NaN  0.9133  1.0363
#
# [29754 rows x 7 columns]

# %%
df.GR.plot()
# Out:
# <AxesSubplot:xlabel='Depth'>

# %%
alias
# Out:
# Total number of aliases: 8
# [('copy', 'copy'),
#  ('ddir', 'dir /ad /on'),
#  ('echo', 'echo'),
#  ('ldir', 'dir /ad /on'),
#  ('ls', 'dir /on'),
#  ('mkdir', 'mkdir'),
#  ('ren', 'ren'),
#  ('rmdir', 'rmdir')]

# %%
tracks = ['MD', 'GR', 'RHOB', ['DT', 'DTS'], 'MD']
well.plot(tracks=tracks)
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\welly\well.py:593: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# C:\Users\acer\Anaconda3\lib\site-packages\welly\well.py:593: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# C:\Users\acer\Anaconda3\lib\site-packages\welly\well.py:599: MatplotlibDeprecationWarning:
# The is_last_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_col() instead.
#   elif ax.is_last_col():

# %%
well.plot()

# %%
well.data['GR']
# Out:
# Curve([5.3274, 5.8235, 6.5228, ...,    nan,    nan,    nan])

# %%
from welly import Curve

# %%
p = {'mnemonic': 'FOO', 'run':0, }
data = [20, 30, 40, 20, 10, 0, 10]
c = Curve(data, basis=[2,3,4,5,6,7,8], params=p)

# %%
c.plot()

# %%
well.unify_basis(start=3800, stop=4500)

# %%
well.plot(tracks=['MD', 'CALI'])
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\welly\well.py:593: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
well.plot_2d(cmap='viridis_r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-62d851db6a0a> in <module>
# ----> 1 well.plot_2d(cmap='viridis_r')
#
# AttributeError: 'Well' object has no attribute 'plot_2d'

# %%
well.data['GR'].plot()

# %%
from striplog import Legend, Striplog
legend = Legend.builtin('NSDOE')

# %%
tracks = ['MD', 'strip', 'GR', 'RHOB', ['DT', 'DTS'], 'M2R9', 'MD']
well.plot(tracks=tracks, legend=legend)
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\welly\well.py:593: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# C:\Users\acer\Anaconda3\lib\site-packages\welly\well.py:593: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# C:\Users\acer\Anaconda3\lib\site-packages\welly\well.py:599: MatplotlibDeprecationWarning:
# The is_last_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_col() instead.
#   elif ax.is_last_col():

# %%
curve_legend_csv = """colour,lw,ls,xlim,xscale,curve mnemonic
#ff0000,1.0,-,"0,200",linear,GR
blue,1.0,-,,linear,RHOB
#00ff00,1.0,--,,linear,DT
#ffff00,1.0,--,,linear,DTS
black,1.0,,,log,M2R9
"""
curve_legend = Legend.from_csv(text=curve_legend_csv)

# %%
complete_legend = legend + curve_legend

# %%
well.data['GR'].plot(legend=curve_legend)

# %%
well.plot(tracks=tracks, legend=complete_legend)
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\welly\well.py:593: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# C:\Users\acer\Anaconda3\lib\site-packages\welly\well.py:599: MatplotlibDeprecationWarning:
# The is_last_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_col() instead.
#   elif ax.is_last_col():

# %% [markdown]
# # Curve

# %%
well = welly.Well.from_las('15-9-19_SR_COMP.LAS')
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\welly\well.py:194: FutureWarning: From v0.5 the default will be 'original', keeping whatever is used in the LAS file. If you want to force conversion to metres, change your code to use `index='m'`.
#   warnings.warn(m, FutureWarning)

# %%
well.plot()

# %%
df = well.df()

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:ylabel='Depth'>

# %%
df = df.reset_index()

# %%
df
# Out:
#            Depth  AC  CALI  DEN      GR  NEU    RDEP    RMED
# 0       102.1568 NaN   NaN  NaN  5.3274  NaN     NaN     NaN
# 1       102.3092 NaN   NaN  NaN  5.8235  NaN     NaN     NaN
# 2       102.4616 NaN   NaN  NaN  6.5228  NaN     NaN     NaN
# 3       102.6140 NaN   NaN  NaN  7.2285  NaN     NaN     NaN
# 4       102.7664 NaN   NaN  NaN  9.5020  NaN     NaN     NaN
# ...          ...  ..   ...  ...     ...  ...     ...     ...
# 29749  4635.9044 NaN   NaN  NaN     NaN  NaN  0.7729  0.5978
# 29750  4636.0568 NaN   NaN  NaN     NaN  NaN  0.8369  0.6257
# 29751  4636.2092 NaN   NaN  NaN     NaN  NaN  0.8741  0.6888
# 29752  4636.3616 NaN   NaN  NaN     NaN  NaN  0.9002  0.8902
# 29753  4636.5140 NaN   NaN  NaN     NaN  NaN  0.9133  1.0363
#
# [29754 rows x 8 columns]

# %%
df[22625:].head(40)
# Out:
#            Depth       AC    CALI     DEN       GR       NEU    RDEP    RMED
# 22625  3550.2068  54.5938  8.8571  2.1705  55.7555   51.2365  1.0708  1.0648
# 22626  3550.3592  54.5938  8.8571  2.1705  55.0681   51.2365  1.0267  1.0262
# 22627  3550.5116  54.5938  8.8571  2.1705  56.0905   51.2365  1.0145  0.9977
# 22628  3550.6640  54.5938  8.8571  2.1705  58.8310   51.2365  1.0348  0.9941
# 22629  3550.8164  54.5938  8.8571  2.1705  60.3862   51.2365  0.9608  1.2204
# 22630  3550.9688  54.5938  8.8571  2.1705  59.1526   51.2365  0.8517  1.4604
# 22631  3551.1212  54.5938  8.8571  2.1705  55.4923   51.2365  0.8655  1.2778
# 22632  3551.2736  54.5938  8.8571  2.1705  52.1964   51.2365  1.0817  0.9530
# 22633  3551.4260  54.5938  8.8571  2.1705  51.3345   51.2365  1.1910  0.8127
# 22634  3551.5784  54.5938  8.8571  2.1705  50.7748   51.2365  1.0447  0.8240
# 22635  3551.7308  54.5938  8.8571  2.1705  49.1649   51.2365  1.0896  0.7641
# ...

# %%
sns.heatmap(df[22625:].isnull())
# Out:
# <AxesSubplot:>
